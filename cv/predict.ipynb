# %%
import cv2
img_predict = cv2.imread('dataset/images/56.jpg')

# %%
from ultralytics import YOLO
model = YOLO("runs/detect/train/weights/best.pt")

# %%
result = model.predict(source=img_predict, conf=0.5) # %50 altındaki güven skoruna sahip tahminleri dikkate alma.
# Out:
# 0: 640x384 1 plaka, 22.0ms
# Speed: 1.8ms preprocess, 22.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)

# %%
result[0].boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.6750])
# data: tensor([[8.2342e+02, 1.6176e+03, 1.3275e+03, 1.7159e+03, 6.7504e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (4165, 2343)
# shape: torch.Size([1, 6])
# xywh: tensor([[1075.4709, 1666.7656,  504.1083,   98.2845]])
# xywhn: tensor([[0.4590, 0.4002, 0.2152, 0.0236]])
# xyxy: tensor([[ 823.4167, 1617.6234, 1327.5250, 1715.9080]])
# xyxyn: tensor([[0.3514, 0.3884, 0.5666, 0.4120]])

# %%
import matplotlib.pyplot as plt

img2 = img_predict.copy()

for box in result[0].boxes:
    x1, y1, x2, y2= map(int, box.xyxy[0])

    cv2.rectangle(img2, (x1,y1), (x2,y2), color=(0,255,0), thickness=5)

plt.imshow(img2)
plt.show()

# %%
# Ödev => OCR nedir? Nasıl yapılır araştırılıp uygulamalı bir markdown dosyası oluştur.
